# %%
import do_functions as do

# %%
df = do.read_and_merge('paz_metadata_actualitzat.pkl',
                       'paz_profiles_actualitzat.pkl')
df = do.clean_dataframe(df)

# %%
initial = [0.1,0.5,1.0,2.0]
final = [0.5,1.0,2.0,5.0,10.0]

for hi in initial:
    for hf in final:
        do.plotROC(df,hi,hf,0.05)

# %%
for hi in initial:
    for hf in final:
        do.plotROC(df,hi,hf,0.1)

# %%
for hi in initial:
    for hf in final:
        do.plotROC(df,hi,hf,0.3)

# %%
for hi in initial:
    for hf in final:
        do.plotROC(df,hi,hf,0.5)

# %%
for hi in initial:
    for hf in final:
        do.plotROC(df,hi,hf,0.7)
